# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#x, y, z = np.loadtxt('data.txt',
#                    skiprows=1,
#                    unpack=True)

# %%
# Generate Distribution:
randomNums = np.random.normal(0,10,100)
#randomNums = np.random.normal(loc = 0, scale = 1, size = (3,3))
randomInts = np.round(randomNums)

# Plot:
x = np.arange(start=min(randomNums), stop = max(randomNums) + 1)
plt.hist(randomInts, bins = x)
#x.std()
#x.mean()
randomInts
# Out:
# array([  7.,  -3., -13.,  -3.,  -0.,   5.,  -1.,  12.,  -3.,   4., -15.,
#          6.,  -0.,   2.,   8.,  16.,  -9., -12.,   3., -12.,  -6.,   5.,
#          0.,  -3., -16.,   4.,   4., -13.,  -6.,   0.,   1.,  17.,   8.,
#         10.,  -9.,   8.,  -6.,   4.,  -5.,  -9., -11.,   3.,   6.,  -6.,
#          4.,   5.,  27.,   9.,  -7.,  -4.,   2., -10.,  -2.,   5.,   4.,
#        -10.,   2., -10.,  -1.,  15.,  -9., -11., -12.,   8.,   4., -12.,
#        -15.,  14., -25.,   2.,   7., -13.,   7.,   3.,   3.,   2.,   1.,
#         19., -14.,   2.,   4., -18.,  16.,  11.,   4.,   0.,  10.,  -8.,
#         15.,  -3.,   1.,  -2.,  20.,  15.,   8., -16., -10., -13., -16.,
#         -6.])

# %%
xa = np.array([-2.35741763, -1.41442086,  1.1072195 ,  0.0276986 , -0.93757657,
       -1.04914042, -1.58922198,  0.37436418,  0.0843064 , -0.99476499,
       -1.67034731, -1.09658411, -0.11959342, -0.75241414,  0.09526389,
        0.66859458,  1.14930409, -0.09929749,  0.27971069,  1.86178174,
        0.9124674 ,  0.67454759, -0.6014737 , -1.99539823, -0.78869026,
        0.64570847,  0.79680868,  1.42226978,  0.3018036 , -1.46018605,
        0.55107634,  0.68996011, -0.95969442,  1.0374661 ,  1.93482906,
        1.59384918,  0.7300422 ,  1.12996234, -0.40083288, -0.80058084,
       -0.5157461 ,  0.3411928 ,  0.33770784,  1.41124116,  1.32234615,
        1.28052093,  0.80672173, -0.30964231,  0.03807472,  1.15006277,
        0.35376706,  1.08794197,  2.95156886,  2.17578387,  1.39556198,
        0.06253635, -0.21720514,  0.20456056,  0.46988572, -0.14799086,
        0.06772131,  0.26812841,  1.12285285,  0.06682931,  0.7679547 ,
        1.10649215, -2.45681202,  0.44666113,  0.03380935,  0.17001685,
       -0.7485711 ,  0.49089498,  1.16311432, -0.62660205, -1.12332037,
        0.2700529 , -0.53073756,  2.14024839,  0.12515058, -1.29109467,
       -1.37225105, -1.5747491 , -0.56993519, -1.08519874,  0.55529345,
        1.93368138,  1.97760807, -0.02945975, -0.7002937 , -1.1499204 ,
       -1.10772516, -1.40943197,  0.02434257,  0.48790241,  0.47083869,
       -0.09580372, -2.00040163,  0.97984976, -0.60763911,  0.762094  ,
        2.50139289, -0.24274003, -0.57435172, -1.1102581 , -0.3878298 ,
        1.63761066,  1.59956984,  3.77256202,  1.3887173 , -0.0309456 ,
        0.47974302,  1.2673402 , -1.01067253,  0.27085949,  0.08205724,
        0.93473564,  0.50546894,  0.76105534,  1.65901855,  0.25590133,
       -0.53297769,  0.79726498,  1.83711776, -0.48676311,  1.0526888 ,
        1.19945923, -0.40797899,  0.83941536,  0.67568007,  0.079049  ,
        0.1101517 ,  2.02767277,  0.28852574,  1.76784371,  1.36174125,
        0.3883399 ,  2.43598   ,  2.47818928, -0.26403811, -0.71989426,
        0.23581437, -0.69162171,  1.05878155,  1.61627427,  0.23512751,
       -0.2763448 , -0.34002222, -0.00586631, -0.63189962,  0.41521861,
        0.59703967, -1.06363652, -0.74101647,  1.25135358,  0.91349765,
       -0.60447436, -0.91153404, -0.00663165,  3.13722006,  2.17246321,
        0.56603148, -0.20473029, -0.38340237,  0.31991283,  1.08744495,
        0.48478832, -1.75687254, -0.18058665, -1.39170277, -2.57070764,
        0.43013149,  0.4336788 , -1.58336643,  0.0998934 ,  1.07799627,
        0.75481213,  0.85276048, -1.98317454, -4.00805178, -2.30370402,
        0.01041292,  0.57176091,  0.9399766 ,  0.36580906, -1.5299043 ,
       -0.14750406,  0.88448229,  1.33611965, -0.26504432, -0.6671139 ,
       -0.06243817,  0.16412048,  0.57789769, -0.05250613, -0.32304065,
       -0.23421957, -0.19368063, -0.2417773 , -0.04039264, -2.31843876])
plt.hist(xa)
# Out:
# (array([ 1.,  2.,  7., 24., 40., 61., 44., 15.,  4.,  2.]),
#  array([-4.00805178, -3.2299904 , -2.45192902, -1.67386764, -0.89580626,
#         -0.11774488,  0.6603165 ,  1.43837788,  2.21643926,  2.99450064,
#          3.77256202]),
#  <a list of 10 Patch objects>)

# %%
with plt.style.context('bmh'):  
    plt.figure(figsize=(10, 3))
    plt.plot(xa)
    print(xa)
# Out:
# [-2.35741763 -1.41442086  1.1072195   0.0276986  -0.93757657 -1.04914042
#  -1.58922198  0.37436418  0.0843064  -0.99476499 -1.67034731 -1.09658411
#  -0.11959342 -0.75241414  0.09526389  0.66859458  1.14930409 -0.09929749
#   0.27971069  1.86178174  0.9124674   0.67454759 -0.6014737  -1.99539823
#  -0.78869026  0.64570847  0.79680868  1.42226978  0.3018036  -1.46018605
#   0.55107634  0.68996011 -0.95969442  1.0374661   1.93482906  1.59384918
#   0.7300422   1.12996234 -0.40083288 -0.80058084 -0.5157461   0.3411928
#   0.33770784  1.41124116  1.32234615  1.28052093  0.80672173 -0.30964231
#   0.03807472  1.15006277  0.35376706  1.08794197  2.95156886  2.17578387
#   1.39556198  0.06253635 -0.21720514  0.20456056  0.46988572 -0.14799086
#   0.06772131  0.26812841  1.12285285  0.06682931  0.7679547   1.10649215
#  -2.45681202  0.44666113  0.03380935  0.17001685 -0.7485711   0.49089498
#   1.16311432 -0.62660205 -1.12332037  0.2700529  -0.53073756  2.14024839
# ...

# %%
#def plotProcess(n_samples=1000):
xxx = w = np.random.normal(size=200)   
for t in range(200):
    xxx[t] = 0.9 * xxx[t-1] + w[t]

with plt.style.context('bmh'):  
    plt.figure(figsize=(10, 3))
    plt.plot(xxx)
        #plt.title("Rho {}\n Dickey-Fuller p-value: {}".format(rho, round(sm.tsa.stattools.adfuller(x)[1], 3)))

#plotProcess()

# %%
xxx
# Out:
# array([-9.88126550e-01, -1.95887271e+00, -1.06084212e+00, -6.52419185e-01,
#        -1.04279900e-01, -1.79920205e+00, -2.66610584e+00, -2.43390704e+00,
#        -1.13820370e+00, -1.64257848e+00, -1.96751218e+00, -1.40644150e+00,
#        -1.17721856e+00, -3.76813902e-01,  7.68652425e-01, -3.39011741e-01,
#        -4.51791930e-01, -1.32281036e+00, -5.08749478e-03, -2.14695134e-02,
#        -8.38468137e-01,  2.27805322e-01,  1.48648841e+00,  1.04197251e+00,
#         1.87740114e+00,  1.67594134e+00,  1.96006660e+00,  2.50430398e+00,
#         1.59926000e-01,  5.96726027e-01, -1.17239937e+00,  1.15034009e+00,
#         3.55409798e-01,  6.74742518e-01,  8.39344256e-01, -3.81099895e-01,
#        -2.27411938e+00, -3.20298486e+00, -4.16265045e+00, -2.31893335e+00,
#        -1.88565795e+00, -1.91590900e-01,  1.44134579e+00,  1.65837401e+00,
#         2.70701564e+00,  3.26727223e+00,  2.56553621e+00,  1.40598495e+00,
# ...

# %%
from scipy.optimize import curve_fit

def func(t, A, h, T, phi):
    return A*np.exp(-h*t)*np.sin(2*np.pi/T*t + phi)

t = np.array([1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016])
y = np.array([1,-7.9,2.8,3.2,2.2,3.9,2.7,2.5,6.2,5.7,3.6,3.2,-0.4,5.6,3.3,3,2.6,5.9,-2.3,-1.1])

popt, pcov = curve_fit(func, t, y, (1e3, 1e-2, 1., -1e1), maxfev=10**6)    
A, h, T, phi = popt

print('A={0}\nh={1}\nT={2}\nphi={3}'.format(*tuple(popt)))

plt.scatter(t, y, s=30, color='orange')
plt.plot(t, func(t, *popt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d78e2c1aa41d> in <module>
#       4     return A*np.exp(-h*t)*np.sin(2*np.pi/T*t + phi)
#       5
# ----> 6 t = np.array([1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016])
#       7 y = np.array([1,-7.9,2.8,3.2,2.2,3.9,2.7,2.5,6.2,5.7,3.6,3.2,-0.4,5.6,3.3,3,2.6,5.9,-2.3,-1.1])
#       8
#
# NameError: name 'np' is not defined

# %%
low,hig =[x.mean() - 3 * x.std(), x.mean() + 3 * x.std()]

# %%
ads = pd.read_csv('iat3.txt', index_col=['Time'], parse_dates=['Time'])
currency = pd.read_csv('currency.csv', index_col=['Time'], parse_dates=['Time'])

# %%
x =ads.Z
x.to_numpy()
# Out:
# array([1785.56813, 1785.56149, 1785.55497, ..., 1785.5707 , 1785.57509,
#        1785.57178])

# %%
plt.plot(x)
# Out:
# c:\users\helg\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#low,hig =[x.mean() - 1.96 * x.std(), x.mean() + 1.96 * x.std()]
low,hig =[x.median() - 1.96 * x.std(), x.median() + 1.96 * x.std()]
std = x.std()
ap = list()
#for i in x:
    #print(i)
#    if i < low:
#        ap.append(i) 
#    if i < hig:
#        ap.append(i)
 #   else
#print(ap)
for it,val in enumerate(x):
    if val <low:
        print(it)
    
ap =np.asarray(ap)    
plt.plot(ap)
print(ap)
#std
#plt.errorbar(x, std, label = 'errorbar', linewidth=2)
# Out:
# 2315
# 2316
# 2317
# 2318
# 2319
# 2320
# 2321
# 2322
# 2323
# 2324
# 2325
# 2326
# 2327
# 2328
# 2329
# 2330
# 2331
# 2332
# 2333
# 2334
# 2335
# 2336
# 2337
# 2338
# 2339
# 2340
# 2341
# 2342
# 2343
# 2344
# 2345
# 2346
# 2347
# 2348
# 2349
# 2350
# 2351
# 2352
# 2353
# 2354
# 2355
# 2356
# 2357
# 2358
# 2359
# 2360
# 2361
# 2362
# 2363
# 2364
# 2365
# 2366
# 2367
# 2368
# 2369
# 2370
# 2371
# 2372
# 2373
# 2374
# 2375
# 2376
# 2377
# 2378
# 2379
# 2380
# 2381
# 2382
# 2383
# 2384
# 2385
# 2386
# 2387
# 2388
# 2389
# 2390
# 2391
# 2392
# 2393
# 2394
# 2395
# 2396
# 2397
# 2398
# 2399
# 2400
# 2401
# 2402
# 2403
# 2404
# 2405
# 2406
# 2407
# 2408
# 2409
# 2410
# 2411
# 2412
# 2413
# 2414
# 2415
# 2416
# 2417
# 2418
# 2419
# 2420
# 2421
# 2422
# 2423
# 2424
# 2425
# 2426
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# 2433
# 2434
# 2435
# 2436
# 2437
# 2438
# 2439
# 2885
# 3915
# []

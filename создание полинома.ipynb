# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.random(1000)*10
noise = np.random.normal(scale=0.3,size=len(x))
y = np.sin(x) + noise
#y = np.sin(x) 
#plot the data
plt.plot(x,y,'ro',alpha=0.4,ms=3,label='data')
#plt.plot(x,y,'ro',alpha=0.3,ms=4,label='data')
plt.xlabel('Time')
plt.ylabel('Intensity')
# Out:
# Text(0, 0.5, 'Intensity')

# %%
#define a moving average function
def moving_average(x,y,step_size=.9,bin_size=1):
    bin_centers  = np.arange(np.min(x),np.max(x)-0.5*step_size,step_size)+0.5*step_size
    bin_avg = np.zeros(len(bin_centers))
    print(bin_centers)
    for index in range(0,len(bin_centers)):
        bin_center = bin_centers[index]
        items_in_bin = y[(x>(bin_center-bin_size*0.5) ) & (x<(bin_center+bin_size*0.5))]
        bin_avg[index] = np.mean(items_in_bin)

    return bin_centers,bin_avg

plt.plot(x,y,'ro',alpha=0.4,ms=3,label='data')
#plt.plot(x,y,'ro',alpha=0.3,ms=4,label='data')
plt.xlabel('Time')
plt.ylabel('Intensity')
#plot the moving average
bins, average = moving_average(x,y)
plt.plot(bins, average,label='moving average')

plt.show()
# Out:
# [0.45609421 1.35609421 2.25609421 3.15609421 4.05609421 4.95609421
#  5.85609421 6.75609421 7.65609421 8.55609421 9.45609421]

# %%
bin_avg = np.zeros(len(bin_centers))
bin_avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-d515b01e79f7> in <module>
# ----> 1 bin_avg = np.zeros(len(bin_centers))
#       2 bin_avg
#
# NameError: name 'bin_centers' is not defined

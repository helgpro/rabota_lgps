# %%
import warnings                                  # `do not disturbe` mode
warnings.filterwarnings('ignore')

import numpy as np                               # vectors and matrices
import pandas as pd                              # tables and data manipulations
import matplotlib.pyplot as plt                  # plots
import seaborn as sns                            # more plots

from dateutil.relativedelta import relativedelta # working with dates with style
from scipy.optimize import minimize              # for function minimization

import statsmodels.formula.api as smf            # statistics and econometrics
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

from itertools import product                    # some useful functions
from tqdm import tqdm_notebook
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit # you have everything done for you
from sklearn.model_selection import cross_val_score
# %matplotlib inline
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
def timeseries_train_test_split(X, y, test_size):
    """
        Сюда заносим х у и размер тестовой выборки
    """
    
    # get the index after which test set starts
    test_index = int(len(X)*(1-test_size))   #          1-03 = 07*дину Х
    
    X_train = X.iloc[:test_index]
    y_train = y.iloc[:test_index]
    X_test = X.iloc[test_index:]
    y_test = y.iloc[test_index:]
    
    return X_train, X_test, y_train, y_test

# %%
def prepareData(series, lag_start, lag_end, test_size, target_encoding=False):

    
    # copy of the initial dataset
    data = pd.DataFrame(series.copy())
    data.columns = ["N"]
    
    # lags of series
    for i in range(lag_start, lag_end):
        data["lag_{}".format(i)] = data.N.shift(i)
    
    # datetime features
    #data.index = pd.to_datetime(data.index)
    #data["hour"] = data.index.hour
    #data["weekday"] = data.index.weekday
    #data['is_weekday'] = data.weekday.isin([5,6])*1
    
    #if target_encoding:
        # calculate averages on train set only
     #   test_index = int(len(data.dropna())*(1-test_size))
        #data['weekday_average'] = list(map(code_mean(data[:test_index], 'weekday', "N").get, data.weekday))
        #data["hour_average"] = list(map(code_mean(data[:test_index], 'hour', "N").get, data.hour))
        #data["is_weekday_average"] = list(map(code_mean(data[:test_index], 'is_weekday', "N").get, data.is_weekday))

        # frop encoded variables 
      #  data.drop(["hour", "weekday",'is_weekday'], axis=1, inplace=True)
    
    # train-test split
    y = data.dropna().N
    X = data.dropna().drop(['N'], axis=1)
    X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=test_size)

    return X_train, X_test, y_train, y_test

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
from sklearn.preprocessing import MinMaxScaler
scaler2 = MinMaxScaler()

# %%
import xgboost as xgb

def XGB_forecast(data, lag_start=1, lag_end=2, test_size=0.15, ):
    
    scale=1.96
    #scale=3
    # для тестой выборки после обучения модели
    #print(test_x)
    # исходные данные
    X_train, X_test, y_train, y_test = prepareData(data, lag_start, lag_end, test_size)
    X_train_scaled = scaler.fit_transform(X_train)
    y_train_scal2 = scaler.fit(X_train)
    print(y_train_scal2)
    X_test_scaled = scaler.fit_transform(X_test)
    dtrain = xgb.DMatrix(X_train_scaled, label=y_train)
#    dtrain = xgb.DMatrix(X_train, label=y_train)
    #print(dtrain)
    dtest = xgb.DMatrix(X_test_scaled)
#    dtest = xgb.DMatrix(X_test)
   

    # задаём параметры
    params = {
        'objective': 'reg:linear',
        'booster':'gblinear'
    }
    trees = 1000

    # прогоняем на кросс-валидации с метрикой rmse
    cv = xgb.cv(params, dtrain, metrics = ('rmse'), verbose_eval=False, nfold=10, show_stdv=False, num_boost_round=trees)
    
    #print('chislo  ',cv['test-rmse-mean'].argmin())
    # обучаем xgboost с оптимальным числом деревьев, подобранным на кросс-валидации
    bst = xgb.train(params, dtrain, num_boost_round=cv['test-rmse-mean'].argmin())

    # можно построить кривые валидации
    #cv.plot(y=['test-mae-mean', 'train-mae-mean'])
    #cv.plot(y=['test-rmse-mean', 'train-rmse-mean'])

    # запоминаем ошибку на кросс-валидации
    deviation = cv.loc[cv['test-rmse-mean'].argmin()]["test-rmse-mean"]

    # посмотрим, как модель вела себя на тренировочном отрезке ряда
#    prediction_train = bst.predict(dtrain)
#    plt.figure(figsize=(25, 15))
#    plt.plot(prediction_train)
#    plt.plot(y_train)
#    plt.axis('tight')
#    plt.grid(True)

    # и на тестовом
    prediction_test = bst.predict(dtest)
    #prediction2_test = bst.predict(dXtest)
   
    lower = prediction_test-scale*deviation
    upper = prediction_test+scale*deviation

    Anomalies = np.array([np.NaN]*len(y_test))
    Anomalies[y_test<lower] = y_test[y_test<lower]
    Anomalies[y_test>upper] = y_test[y_test>upper]

    plt.figure(figsize=(15, 5))
    plt.plot(list(y_test), label="y_test")
    plt.plot(prediction_test, label="prediction")
    plt.plot(lower, "g--", label="upper bond / lower bond")
    plt.plot(upper, "g--")
    #plt.plot(list(y_test), label="y_test")
    plt.plot(Anomalies, "ro", markersize=10)
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("XGBoost  mean_absolute_percentage_error {} ".format(round(mean_absolute_error(prediction_test, y_test))))
    plt.grid(True)
    plt.legend()
    
   
    #return(prediction2_test)

# %%
data = pd.read_csv('iat3_lon_n_t.txt', index_col=['Time'], parse_dates=['Time'])
#data = pd.read_csv('iat3_lon_polynom.txt', index_col=['Time'], parse_dates=['Time']) # trend
#data = pd.read_csv('iat3_X_n_t.txt', index_col=['Time'], parse_dates=['Time']) # trend
#data = pd.read_csv('iv16_X_n_t.txt', index_col=['Time'], parse_dates=['Time']) # trend
#iat3 = pd.read_csv('iat3.txt', index_col=['Time'], parse_dates=['Time'])
#data = pd.read_csv('iat3H_cut.txt', index_col=['Time'], parse_dates=['Time'])
#len(data)
#data = pd.read_csv('iat3_clear.txt', index_col=['Time'], parse_dates=['Time'])
#X_train, X_test, y_train, y_test = prepareData(data, 5, 30, 0.2)
#X_train
plt.plot(data)
#plt.plot(iat3)
#y = data.to_numpy()

#for i in data.N:    
#    print(i)
#    y= np.append(i))

# %%
# %time
XGB_forecast(data, test_size=0.2, lag_start=20, lag_end=50)
# Out:
# Wall time: 0 ns
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [11:27:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:27:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:27:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:27:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:27:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
#daset = pd.read_csv('iat3_Y_cut.txt',',', index_col=['Time'], parse_dates=['Time'],dayfirst=True)
daset = pd.read_csv('iat3_lat.txt', index_col=['Time'], parse_dates=['Time'])
#daset = pd.read_csv('iat3_Y_cut.txt',',', index_col=['Time'], parse_dates=['Time'],dayfirst=True)
ds = daset.N
ds.plot(figsize=(12,6))

# %%
XGB_forecast(daset, test_size=0.2, lag_start=15, lag_end=35)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [11:28:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %% [markdown]
# ### метод преобразования частоты и повторной выборки временных рядов.

# %%
dsr = ds.resample('d', how='mean')
dsr.plot(figsize=(12,6))

# %%
XGB_forecast(dsr, test_size=0.3, lag_start=12, lag_end=20)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [11:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
dsdiff = ds.diff(periods=1).dropna()
ds.plot(figsize=(12,6))

# %%
dsdiff.plot(figsize=(12,6))

# %%
dsdiff.head()
# Out:
# Time
# 2005-07-27    1.000018e-10
# 2005-07-28    1.900000e-08
# 2005-09-28   -4.220000e-08
# 2005-09-29    6.999983e-10
# 2005-09-30    9.200001e-09
# Name: N, dtype: float64

# %%
XGB_forecast(dsdiff, test_size=0.35, lag_start=5, lag_end=20)
#XGB_forecast(dsdiff, test_size=0.2, lag_start=1, lag_end=2)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [11:28:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:28:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
 from sklearn.metrics import accuracy_score

# %%
# %%time
wet = pd.read_csv('iat3_lon_n_t.txt',',', index_col=['Time'], parse_dates=['Time'],dayfirst=True)
#wet = pd.read_csv('iat3_alt.txt', index_col=['Time'], parse_dates=['Time'])
we = wet.N
    
scale=1.96
#scale=2.2
# для тестой выборки после обучения модели
#print(test_x)
# исходные данные dsdiff
X_train, X_test, y_train, y_test = prepareData(we, 30, 60, 0.6)
#X_train, X_test, y_train, y_test = prepareData(we, 1, 5, 0.2)
#macciv dlya viborki predskaz polnogo ryada
pred_X = pd.concat([X_train, X_test])
pred_y = pd.concat([y_train, y_test])
print(len(pred_y))
#X_train_scaled = scaler.fit_transform(X_train)
#dtrain = xgb.DMatrix(X_train_scaled, label=y_train)
dtrain = xgb.DMatrix(X_train, label=y_train)
#print(dtrain)
dtest = xgb.DMatrix(pred_X)
dpredtest = xgb.DMatrix(pred_X)


# задаём параметры
params = {
    'objective': 'reg:linear',
    'booster':'gblinear'
}
trees = 1000

# прогоняем на кросс-валидации с метрикой rmse
cv = xgb.cv(params, dtrain, metrics = ('rmse'), verbose_eval=False, nfold=10, show_stdv=False, num_boost_round=trees)

#print('chislo  ',cv['test-rmse-mean'].argmin())
# обучаем xgboost с оптимальным числом деревьев, подобранным на кросс-валидации
bst = xgb.train(params, dtrain, num_boost_round=cv['test-rmse-mean'].argmin())

# можно построить кривые валидации
#cv.plot(y=['test-mae-mean', 'train-mae-mean'])
#cv.plot(y=['test-rmse-mean', 'train-rmse-mean'])

# запоминаем ошибку на кросс-валидации
deviation = cv.loc[cv['test-rmse-mean'].argmin()]["test-rmse-mean"]


# и на тестовом
prediction_test = bst.predict(dpredtest)
#prediction2_test = bst.predict(dXtest)

lower = prediction_test-scale*deviation
upper = prediction_test+scale*deviation

Anomalies = np.array([np.NaN]*len(pred_y))
Anomalies[pred_y<lower] = pred_y[pred_y<lower]
Anomalies[pred_y>upper] = pred_y[pred_y>upper]

plt.figure(figsize=(15, 5))
plt.plot(list(pred_y), label="Исходные данные")
plt.plot(prediction_test, label="предсказание")
plt.ylabel(r'longitude  ', {'color': 'C0', 'fontsize': 20})
plt.xlabel(r'Время', {'color': 'C0', 'fontsize': 20})      
plt.plot(lower, "g--", label="верх / нижн граница")
plt.plot(upper, "g--")
#plt.plot(list(y_test), label="y_test")
plt.plot(Anomalies, "ro", markersize=10)
plt.legend(loc="best")
plt.axis('tight')
plt.title("XGBoost  Средняя обсолютная ошибка MAE {} ".format(round(mean_absolute_error(prediction_test, pred_y))))
#plt.title("XGBoost  Средняя обсолютная ошибка MAE {} ".format(round(mean_absolute_percentage_error(prediction_test, pred_y))))
plt.grid(True)
plt.legend()
# Out:
# 3924
# [11:29:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:29:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:29:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:29:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [11:29:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
prediction_test
#pred_y
# Out:
# array([ -945.3214, -1024.8904, -1017.0419, ..., -1068.2834, -1149.475 ,
#        -1119.643 ], dtype=float32)

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostRegressor
model=CatBoostRegressor(iterations=50, depth=3, learning_rate=0.1, loss_function='RMSE')
#y_train
#categorical_features_indices = np.where(X.dtypes != np.float)[0]
model.fit(X_train, y_train,plot=True)
expected_y  = y_test
predicted_y = model.predict(X_test)
    
    # summarize the fit of the model
print('R2'); print(metrics.r2_score(expected_y, predicted_y))
print('MSLE'); print(metrics.mean_squared_log_error(expected_y, predicted_y))
    
#plt.figure(figsize=(10,10))     
#sns.regplot(expected_y, predicted_y, fit_reg=True, scatter_kws={"s": 100})
#Snippet_168()
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
# ...

# %%
import catboost as ctb
from sklearn import metrics
model = ctb.CatBoostRegressor(iterations=50, depth=3, learning_rate=0.1, loss_function='RMSE')
model.fit(X_train, y_train)
#print(model)
    
    # make predictions
expected_y  = y_test
#predicted_y = model.predict(X_test)
predicted_y = model.predict(pred_X)
    
    # summarize the fit of the model
print(); print(metrics.r2_score(expected_y, predicted_y))
print(); print(metrics.mean_squared_log_error(expected_y, predicted_y))
    
plt.figure(figsize=(10,10))     
sns.regplot(expected_y, predicted_y, fit_reg=True, scatter_kws={"s": 100})
#Snippet_168()
# Out:
# 0:	learn: 840.7730087	total: 2.13ms	remaining: 105ms
# 1:	learn: 784.2467154	total: 4.2ms	remaining: 101ms
# 2:	learn: 735.6416433	total: 5.66ms	remaining: 88.7ms
# 3:	learn: 691.4103362	total: 7.5ms	remaining: 86.2ms
# 4:	learn: 654.9115611	total: 8.77ms	remaining: 78.9ms
# 5:	learn: 621.8363243	total: 10.1ms	remaining: 73.8ms
# 6:	learn: 592.6834756	total: 11.5ms	remaining: 70.9ms
# 7:	learn: 566.7595106	total: 13.3ms	remaining: 69.7ms
# 8:	learn: 543.7168645	total: 14.7ms	remaining: 67ms
# 9:	learn: 525.9272137	total: 16ms	remaining: 64ms
# 10:	learn: 508.6702359	total: 17.3ms	remaining: 61.2ms
# 11:	learn: 494.7008258	total: 18.6ms	remaining: 58.8ms
# 12:	learn: 482.3177717	total: 19.8ms	remaining: 56.4ms
# 13:	learn: 471.3225843	total: 21ms	remaining: 54.1ms
# 14:	learn: 461.3085228	total: 22.3ms	remaining: 52ms
# 15:	learn: 452.4754597	total: 23.6ms	remaining: 50.1ms
# 16:	learn: 445.3546074	total: 24.9ms	remaining: 48.3ms
# ...

# %%
plt.figure(figsize=(20,10)) 
plt.plot(predicted_y)
plt.plot(list(y_test))
#len(y_test)
plt.plot(list(y_test), label="Исходные данные")
plt.plot(predicted_y, label="предсказание")
#plt.plot(lower, "g--", label="верх / нижн граница")
#plt.plot(upper, "g--")
#plt.plot(list(y_test), label="y_test")
#plt.plot(Anomalies, "ro", markersize=10)
#plt.legend(loc="best")
#plt.axis('tight')
plt.title("XGBoost  mean_absolute_percentage_error {} ".format(round(mean_absolute_error(predicted_y, y_test))))
plt.grid(True)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-523d8ccbd9b6> in <module>
#      11 #plt.legend(loc="best")
#      12 #plt.axis('tight')
# ---> 13 plt.title("XGBoost  mean_absolute_percentage_error {} ".format(round(mean_absolute_error(predicted_y, y_test))))
#      14 plt.grid(True)
#      15 plt.legend()
#
# c:\users\helg\myvirt\lib\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     176     """
#     177     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 178         y_true, y_pred, multioutput)
#     179     check_consistent_length(y_true, y_pred, sample_weight)
#     180     output_errors = np.average(np.abs(y_pred - y_true),
#
# c:\users\helg\myvirt\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
# ...

# %%
predicted_X_y = model.predict(pred_X)
plt.figure(figsize=(20,10)) 
plt.plot(predicted_y)
plt.plot(list(pred_y), label="Исходные данные")
plt.plot(predicted_X_y, label="предсказание")
#plt.plot(lower, "g--", label="верх / нижн граница")
#plt.plot(upper, "g--")
#plt.plot(list(y_test), label="y_test")
#plt.plot(Anomalies, "ro", markersize=10)
#plt.legend(loc="best")
#plt.axis('tight')
plt.title("CatBoost  mean_absolute_error {} ".format(round(mean_absolute_error(predicted_X_y, pred_y))))
plt.grid(True)
plt.legend()

# %%
#pip install lightgbm
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
gbm = lgb.LGBMRegressor(num_leaves=31,
                        learning_rate=0.05,
                        n_estimators=20)
gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric='l1',
        early_stopping_rounds=5)

print('Starting predicting...')
# predict
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration_)
# eval
print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
def rmsle(y_true, y_pred):
    return 'RMSLE', np.sqrt(np.mean(np.power(np.log1p(y_pred) - np.log1p(y_true), 2))), False


print('Starting training with custom eval function...')
# train
gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric=rmsle,
        early_stopping_rounds=5)


# another self-defined eval metric
# f(y_true: array, y_pred: array) -> name: string, eval_result: float, is_higher_better: bool
# Relative Absolute Error (RAE)
def rae(y_true, y_pred):
    return 'RAE', np.sum(np.abs(y_pred - y_true)) / np.sum(np.abs(np.mean(y_true) - y_true)), False


print('Starting training with multiple custom eval functions...')
# train
gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric=lambda y_true, y_pred: [rmsle(y_true, y_pred), rae(y_true, y_pred)],
        early_stopping_rounds=5)

print('Starting predicting...')
# predict
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration_)
# eval
print('The rmsle of prediction is:', rmsle(y_test, y_pred)[1])
print('The rae of prediction is:', rae(y_test, y_pred)[1])

# other scikit-learn modules
estimator = lgb.LGBMRegressor(num_leaves=31)

param_grid = {
    'learning_rate': [0.01,0.05,0.5, 0.1, 1],
    'n_estimators': [10,20,30, 40,80]
}

gbm = GridSearchCV(estimator, param_grid, cv=3)
gbm.fit(X_train, y_train)

print('Best parameters found by grid search are:', gbm.best_params_)
# Out:
# [1]	valid_0's l1: 716.82	valid_0's l2: 715558
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l1: 682.687	valid_0's l2: 651676
# [3]	valid_0's l1: 650.679	valid_0's l2: 595017
# [4]	valid_0's l1: 619.623	valid_0's l2: 543168
# [5]	valid_0's l1: 591.291	valid_0's l2: 497844
# [6]	valid_0's l1: 563.67	valid_0's l2: 456500
# [7]	valid_0's l1: 538.079	valid_0's l2: 420285
# [8]	valid_0's l1: 513.484	valid_0's l2: 387337
# [9]	valid_0's l1: 489.567	valid_0's l2: 356930
# [10]	valid_0's l1: 469.277	valid_0's l2: 332155
# [11]	valid_0's l1: 449.563	valid_0's l2: 309148
# [12]	valid_0's l1: 431.982	valid_0's l2: 289304
# [13]	valid_0's l1: 414.852	valid_0's l2: 270806
# [14]	valid_0's l1: 400.098	valid_0's l2: 254909
# [15]	valid_0's l1: 385.782	valid_0's l2: 240914
# [16]	valid_0's l1: 372.287	valid_0's l2: 227918
# [17]	valid_0's l1: 360.6	valid_0's l2: 216772
# [18]	valid_0's l1: 349.096	valid_0's l2: 206571
# [19]	valid_0's l1: 339.053	valid_0's l2: 197758
# ...

# %%
gbm = lgb.LGBMRegressor(num_leaves=31,
                        learning_rate=0.1,
                        n_estimators=40)
gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric=lambda y_true, y_pred: [rmsle(y_true, y_pred), rae(y_true, y_pred)],
        early_stopping_rounds=5)
prdict_lgb = gbm.predict(pred_X)
plt.plot(list(pred_y))
plt.plot(prdict_lgb)
# Out:
# [1]	valid_0's l2: 648836	valid_0's RMSLE: nan	valid_0's RAE: 0.926362
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l2: 539064	valid_0's RMSLE: nan	valid_0's RAE: 0.839248
# [3]	valid_0's l2: 449951	valid_0's RMSLE: nan	valid_0's RAE: 0.7601
# [4]	valid_0's l2: 379093	valid_0's RMSLE: nan	valid_0's RAE: 0.690037
# [5]	valid_0's l2: 323532	valid_0's RMSLE: nan	valid_0's RAE: 0.62833
# [6]	valid_0's l2: 280280	valid_0's RMSLE: nan	valid_0's RAE: 0.577454
# Early stopping, best iteration is:
# [1]	valid_0's l2: 648836	valid_0's RMSLE: nan	valid_0's RAE: 0.926362

# %%
data = pd.read_csv('iat3_lon_n_t.txt', index_col=['Time'], parse_dates=['Time'])

# %%
stdN =data.N.std()
minN=data.N.min()
maxN=data.N.max()
meanN=data.N.mean()
#(xi-xср\std) 
# (xi-min\(max-min))
Xnorm = [(data.N[i]-minN)/(maxN-minN) for i in range(0, len(data.N))] # Создает х от 0 до длены серии
Xstand = [(data.N[i]-meanN)/(stdN-minN) for i in range(0, len(data.N))] # Создает х от 0 до длены серии
Xstand
# Out:
# [-0.23115063315602938,
#  -0.23158555330961228,
#  -0.29175281574992157,
#  -0.23550880408510916,
#  -0.2664778289220026,
#  -0.25622581243642684,
#  -0.20933287033087836,
#  -0.22083640343216132,
#  -0.25314129534894964,
#  -0.19498890214143036,
#  -0.21603434295624793,
#  -0.21570591049274807,
#  -0.18388918257458417,
#  -0.16638531622672212,
#  -0.1670110745345757,
#  -0.16362923160274478,
#  -0.17990371856079507,
#  -0.20018580675852984,
#  -0.22046789495626468,
#  -0.1869336236496645,
#  -0.17610909270127661,
#  -0.18265083379152167,
#  -0.26781789444129145,
#  -0.20145946060013248,
#  -0.20971874507881366,
#  -0.19087901165105675,
#  -0.2346341928240866,
#  -0.19938237812905021,
#  -0.19122958134045204,
#  -0.18307678455185383,
#  -0.2188167632455146,
#  -0.21428989138805957,
#  -0.1914425567206181,
#  -0.16267923927078531,
#  -0.13830519936917834,
#  -0.0988549452801868,
#  -0.22333466570971897,
#  -0.20430409412769135,
#  -0.1932887250250328,
#  -0.20421974366350373,
# ...

# %%
new = pd.Series(Xstand, index = data.index)

# %%
# %%time
we = new
    
scale=1.96
#scale=2.2
# для тестой выборки после обучения модели
#print(test_x)
# исходные данные dsdiff
X_train, X_test, y_train, y_test = prepareData(we, 25, 40, 0.2)
#X_train, X_test, y_train, y_test = prepareData(we, 1, 5, 0.2)
#macciv dlya viborki predskaz polnogo ryada
pred_X = pd.concat([X_train, X_test])
pred_y = pd.concat([y_train, y_test])
print(len(pred_y))
#X_train_scaled = scaler.fit_transform(X_train)
#dtrain = xgb.DMatrix(X_train_scaled, label=y_train)
dtrain = xgb.DMatrix(X_train, label=y_train)
#print(dtrain)
dtest = xgb.DMatrix(pred_X)
dpredtest = xgb.DMatrix(pred_X)


# задаём параметры
params = {
    'objective': 'reg:linear',
    'booster':'gblinear'
}
trees = 1000

# прогоняем на кросс-валидации с метрикой rmse
cv = xgb.cv(params, dtrain, metrics = ('rmse'), verbose_eval=False, nfold=10, show_stdv=False, num_boost_round=trees)

#print('chislo  ',cv['test-rmse-mean'].argmin())
# обучаем xgboost с оптимальным числом деревьев, подобранным на кросс-валидации
bst = xgb.train(params, dtrain, num_boost_round=cv['test-rmse-mean'].argmin())

# можно построить кривые валидации
#cv.plot(y=['test-mae-mean', 'train-mae-mean'])
#cv.plot(y=['test-rmse-mean', 'train-rmse-mean'])

# запоминаем ошибку на кросс-валидации
deviation = cv.loc[cv['test-rmse-mean'].argmin()]["test-rmse-mean"]


# и на тестовом
prediction_test = bst.predict(dpredtest)
#prediction2_test = bst.predict(dXtest)

lower = prediction_test-scale*deviation
upper = prediction_test+scale*deviation

Anomalies = np.array([np.NaN]*len(pred_y))
Anomalies[pred_y<lower] = pred_y[pred_y<lower]
Anomalies[pred_y>upper] = pred_y[pred_y>upper]

plt.figure(figsize=(15, 5))
plt.plot(list(pred_y), label="Исходные данные")
plt.plot(prediction_test, label="предсказание")
plt.ylabel(r'longitude  ', {'color': 'C0', 'fontsize': 20})
plt.xlabel(r'Время', {'color': 'C0', 'fontsize': 20})      
plt.plot(lower, "g--", label="верх / нижн граница")
plt.plot(upper, "g--")
#plt.plot(list(y_test), label="y_test")
plt.plot(Anomalies, "ro", markersize=10)
plt.legend(loc="best")
plt.axis('tight')
plt.title("XGBoost  Средняя обсолютная ошибка в процентах MAPE {} ".format(round(mean_absolute_percentage_error(prediction_test, pred_y))))
#plt.title("XGBoost  Средняя обсолютная ошибка MAE {} ".format(round(mean_absolute_percentage_error(prediction_test, pred_y))))
plt.grid(True)
plt.legend()
# Out:
# 3944
# [15:13:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.0.0/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
def tsplot(y, lags=None, figsize=(12, 7), style='bmh'):
    """
        Plot time series, its ACF and PACF, calculate Dickey–Fuller test
        
        y - timeseries
        lags - how many lags to include in ACF, PACF calculation
    """
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (2, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()

# %%
tsplot(data.N, lags=60)

# %%
ads_diff = data.N - data.N.shift(24)
tsplot(ads_diff[24:], lags=60)

# %%
ads_diff = ads_diff - ads_diff.shift(1)
tsplot(ads_diff[24+1:], lags=60)

# %%
ps = range(2, 5)
d=1 
qs = range(2, 5)
Ps = range(0, 2)
D=1 
Qs = range(0, 2)
s = 24 # season length is still 24

# creating list with all the possible combinations of parameters
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 36

# %%
def optimizeSARIMA(parameters_list, d, D, s):
    """
        Return dataframe with parameters and corresponding AIC
        
        parameters_list - list with (p, q, P, Q) tuples
        d - integration order in ARIMA model
        D - seasonal integration order 
        s - length of season
    """
    
    results = []
    best_aic = float("inf")

    for param in tqdm_notebook(parameters_list):
        # we need try-except because on some combinations model fails to converge
        try:
            model=sm.tsa.statespace.SARIMAX(data.N, order=(param[0], d, param[1]), 
                                            seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
        except:
            continue
        aic = model.aic
        # saving best model, AIC and parameters
        if aic < best_aic:
            best_model = model
            best_aic = aic
            best_param = param
        results.append([param, model.aic])

    result_table = pd.DataFrame(results)
    result_table.columns = ['parameters', 'aic']
    # sorting in ascending order, the lower AIC is - the better
    result_table = result_table.sort_values(by='aic', ascending=True).reset_index(drop=True)
    
    return result_table

# %%
# %%time
result_table = optimizeSARIMA(parameters_list, d, D, s)
# Out:
# ...
# Wall time: 1h 23min 44s

# %%
result_table.head()
# Out:
#      parameters           aic
# 0  (2, 2, 0, 1)  54030.685818
# 1  (3, 3, 1, 1)  54030.758037
# 2  (3, 3, 0, 1)  54030.893696
# 3  (2, 4, 0, 1)  54031.203288
# 4  (3, 2, 0, 1)  54032.361686

# %%
# set the parameters that give the lowest AIC
p, q, P, Q = result_table.parameters[0]

best_model=sm.tsa.statespace.SARIMAX(data.N, order=(p, d, q), 
                                        seasonal_order=(P, D, Q, s)).fit(disp=-1)
print(best_model.summary())
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                                  N   No. Observations:                 3983
# Model:             SARIMAX(2, 1, 2)x(0, 1, 1, 24)   Log Likelihood              -27009.343
# Date:                            Fri, 27 Mar 2020   AIC                          54030.686
# Time:                                    13:02:17   BIC                          54068.387
# Sample:                                         0   HQIC                         54044.057
#                                            - 3983
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8778      0.011    -82.436      0.000      -0.899      -0.857
# ar.L2          0.1163      0.010     11.376      0.000       0.096       0.136
# ...

# %%
tsplot(best_model.resid[24+1:], lags=60)

# %%
def plotSARIMA(series, model, n_steps):
    """
        Plots model vs predicted values
        
        series - dataset with timeseries
        model - fitted SARIMA model
        n_steps - number of steps to predict in the future
        
    """
    # adding model values
    data = series.copy()
    data.columns = ['actual']
    data['arima_model'] = model.fittedvalues
    # making a shift on s+d steps, because these values were unobserved by the model
    # due to the differentiating
    data['arima_model'][:s+d] = np.NaN
    #print(data)
    # forecasting on n_steps forward 
    
    forecast = model.predict(start = data.shape[0], end = data.shape[0]+n_steps)
    #print(forecast)
    forecast = data.arima_model.append(forecast)
    #print(forecast)
    #fcend = (forecast.index[-1])
    #tal = forecast.tail(n_steps)
    # calculate error, again having shifted on s+d steps from the beginning
    error = mean_absolute_percentage_error(data['actual'][s+d:], data['arima_model'][s+d:])
    predskazaniya = pd.Series(['2019-01-31,-1545.836961',
                              '2019-01-01,-1540.836658',
                              '2019-01-02,-1539.244921',
                              '2019-01-03,-1542.276420',
                              '2019-01-04,-1567.148014',
                              '2019-01-05,-1519.039834',
                              '2019-01-06,-1574.250155',
                              '2019-01-07,-1517.883539',
                              '2019-01-08,-1569.289663',
                              '2019-01-09,-1557.157064',
                              '2019-01-10,-1545.301989',
                              '2019-01-11,-1520.886351',
                              '2019-01-12,-1530.652095',
                              '2019-01-13,-1534.024564',
                              '2019-01-14,-1558.642776',
                              '2019-01-15,-1537.933042',
                              '2019-01-16,-1561.924512',
                              '2019-01-17,-1526.004009',
                              '2019-01-18,-1545.672932',
                              '2019-01-19,-1541.063246',
                              '2019-01-20,-1555.769602'])
    #fff = data['arima_model'].append(predskazaniya,ignore_index=True)
    plt.figure(figsize=(15, 7))
    plt.title("Mean Absolute Percentage Error: {0:.2f}%".format(error))
    #plt.plot(tal, color='r', label="model")
    #print(forecast.tail(20))
    #plt.axvspan(data.index[-1],4033, alpha=0.5, color='lightgrey') # рисует квадрат
    #plt.plot(data.actual, label="actual")
    plt.plot(data['arima_model'])
    #print(fff)
    #plt.legend()
    plt.grid(True);
    return(data['arima_model'])

# %%
fc = plotSARIMA(data, best_model,20)
#fcarr = [fc.index[i] for i in range(0, len(fc))] # Создает х от 0 до длены серии

# %%
#data['arima_model']
fc
# Out:
# Time
# 2005-07-26            NaN
# 2005-07-27            NaN
# 2005-07-28            NaN
# 2005-09-28            NaN
# 2005-09-29            NaN
# 2005-09-30            NaN
# 2005-10-27            NaN
# 2005-10-28            NaN
# 2005-10-29            NaN
# 2005-10-30            NaN
# 2005-11-14            NaN
# 2005-11-15            NaN
# 2005-11-16            NaN
# 2005-11-17            NaN
# 2005-11-18            NaN
# 2005-11-19            NaN
# 2005-11-20            NaN
# 2005-11-21            NaN
# 2005-11-22            NaN
# 2005-11-23            NaN
# 2005-11-24            NaN
# 2005-11-25            NaN
# 2005-11-26            NaN
# 2005-11-27            NaN
# 2005-11-28            NaN
# 2005-11-29   -1165.222856
# 2005-11-30   -1368.885803
# 2005-12-01   -1046.549763
# 2005-12-02   -1201.791331
# 2005-12-03   -1071.579883
#                  ...
# 2018-12-02   -1330.489841
# 2018-12-03   -1341.705798
# 2018-12-04   -1353.131981
# 2018-12-05   -1319.942085
# ...

# %%
type(fc)
ata = fc.tolist()
#print(ata)
f= open("sarima.csv","w+")
for i in range(len(ata)):
    print(ata[i])
    f.write(str(ata))
    f.write('\n')
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# -1165.2228557235674
# -1368.8858031610382
# -1046.549763443879
# -1201.791330620059
# -1071.5798826463533
# -814.3884903069879
# -1002.6281439029106
# -1174.6805892504133
# -818.5403931977868
# -939.9286690407026
# -856.5639713021748
# -592.9254003491172
# -741.2368898311877
# -816.8387571981651
# -840.3770044622427
# -985.2357126665012
# -1113.0205698962473
# -1242.9706476916244
# -998.0623838659446
# -998.2703486952737
# -1084.677731188349
# -1531.1690810085674
# -1090.2598911657017
# -1257.7187963811514
# -1112.0360890559957
# -1385.0072340098013
# -1097.3065194846442
# -1211.5171186335076
# -1085.9925993068061
# -763.5948360963049
# -900.4732401368167
# -945.2617359286305
# -717.5813382835113
# -1059.4926250511485
# -882.5511072829635
# -1235.7009568992282
# -1012.2503938619484
# -1051.9310826221085
# -1148.5042305961158
# ...

# %%
data = series.copy()
data.columns = ['actual']
sara = pd.read_csv('sarima2.csv', index_col=['Time'], parse_dates=['Time'])
plt.plot(sara)
# Out:
#                       N
# Time
# 2019-01-11 -1545.301989
# 2019-01-12 -1520.886351
# 2019-01-13 -1530.652095
# 2019-01-14 -1534.024564
# 2019-01-15 -1558.642776
# 2019-01-16 -1537.933042
# 2019-01-17 -1561.924512
# 2019-01-18 -1526.004009
# 2019-01-19 -1545.672932
# 2019-01-20 -1541.063246
